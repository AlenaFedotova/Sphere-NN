# %% [markdown]
# ## Семинар 10: "Генерация текстов"

# %% [markdown]
# ФИО:

# %%
import numpy as np
import re
from torch import nn
from torch.autograd import Variable
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
import sys
# %matplotlib inline

# %% [markdown]
# Этот семинар посвящен чат-ботам. Вам предстоит реализовать модель, генерирующую определенные тексты. В качестве текстов можно взять сборник цитат умных людей, предсказаний и т.д. На семинаре мы используем данные https://github.com/alvations/Quotables/blob/master/author-quote.txt
#
# При реализации задания вы можете пользоваться кодом из этого примера: <a href=https://github.com/spro/practical-pytorch/blob/master/char-rnn-generation/char-rnn-generation.ipynb>Generating Shakespeare with a Character-Level RNN</a>

# %% [markdown]
# ### Часть 1: подготовка данных

# %% [markdown]
# Реализуйте датасет для дальнейшего обучения (будем использовать batch size=1)

# %%
! tail -n 2 author-quote.txt
# Out:
# Zsa Zsa Gabor	I love to put on diamonds and beautiful evening gowns and make my girl-friends upset.

# %%
! wc -l author-quote.txt
# Out:
# 36166 author-quote.txt

# %%
lines = [x.split('\t')[1].strip() for x in open('author-quote.txt').readlines()]

# %%
plt.hist(list(map(len, lines)), bins=100)
# Out:
# (array([  3.00000000e+00,   2.00000000e+01,   6.20000000e+01,
#           1.64000000e+02,   2.46000000e+02,   3.44000000e+02,
#           4.18000000e+02,   5.29000000e+02,   6.99000000e+02,
#           7.24000000e+02,   8.80000000e+02,   9.32000000e+02,
#           9.30000000e+02,   9.55000000e+02,   1.01100000e+03,
#           1.00300000e+03,   1.01000000e+03,   1.01000000e+03,
#           9.12000000e+02,   9.56000000e+02,   9.58000000e+02,
#           9.91000000e+02,   9.35000000e+02,   9.22000000e+02,
#           9.20000000e+02,   7.70000000e+02,   6.29000000e+02,
#           6.27000000e+02,   5.77000000e+02,   5.76000000e+02,
#           6.02000000e+02,   5.88000000e+02,   5.21000000e+02,
#           5.67000000e+02,   5.19000000e+02,   5.28000000e+02,
#           5.61000000e+02,   5.49000000e+02,   5.31000000e+02,
#           4.96000000e+02,   4.83000000e+02,   4.45000000e+02,
#           4.75000000e+02,   4.46000000e+02,   3.99000000e+02,
#           4.28000000e+02,   4.09000000e+02,   3.74000000e+02,
#           3.31000000e+02,   3.23000000e+02,   3.03000000e+02,
#           3.27000000e+02,   3.14000000e+02,   3.04000000e+02,
#           2.65000000e+02,   2.48000000e+02,   2.73000000e+02,
#           2.53000000e+02,   2.28000000e+02,   2.40000000e+02,
#           2.32000000e+02,   2.20000000e+02,   2.19000000e+02,
#           1.92000000e+02,   2.19000000e+02,   1.76000000e+02,
#           1.64000000e+02,   1.39000000e+02,   1.19000000e+02,
#           1.17000000e+02,   1.21000000e+02,   1.06000000e+02,
#           1.20000000e+02,   9.90000000e+01,   7.40000000e+01,
#           1.04000000e+02,   8.80000000e+01,   8.50000000e+01,
#           9.70000000e+01,   7.30000000e+01,   9.50000000e+01,
#           6.10000000e+01,   5.20000000e+01,   6.20000000e+01,
#           4.70000000e+01,   3.40000000e+01,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   2.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           2.00000000e+00]),
#  array([   9.  ,   12.99,   16.98,   20.97,   24.96,   28.95,   32.94,
#           36.93,   40.92,   44.91,   48.9 ,   52.89,   56.88,   60.87,
#           64.86,   68.85,   72.84,   76.83,   80.82,   84.81,   88.8 ,
#           92.79,   96.78,  100.77,  104.76,  108.75,  112.74,  116.73,
#          120.72,  124.71,  128.7 ,  132.69,  136.68,  140.67,  144.66,
#          148.65,  152.64,  156.63,  160.62,  164.61,  168.6 ,  172.59,
#          176.58,  180.57,  184.56,  188.55,  192.54,  196.53,  200.52,
#          204.51,  208.5 ,  212.49,  216.48,  220.47,  224.46,  228.45,
#          232.44,  236.43,  240.42,  244.41,  248.4 ,  252.39,  256.38,
#          260.37,  264.36,  268.35,  272.34,  276.33,  280.32,  284.31,
#          288.3 ,  292.29,  296.28,  300.27,  304.26,  308.25,  312.24,
#          316.23,  320.22,  324.21,  328.2 ,  332.19,  336.18,  340.17,
#          344.16,  348.15,  352.14,  356.13,  360.12,  364.11,  368.1 ,
#          372.09,  376.08,  380.07,  384.06,  388.05,  392.04,  396.03,
#          400.02,  404.01,  408.  ]),
#  <a list of 100 Patch objects>)

# %%
line = lines[0]

# %%
line
# Out:
# 'If you live to be a hundred, I want to live to be a hundred minus one day so I never have to live without you.'

# %%
lines = list(filter(lambda x: len(x) <= 50, lines))
print(lines)
# Out:
# ['Weeds are flowers too, once you get to know them.', 'To the uneducated, an A is just three sticks.', "Tiggers don't like honey.", 'No sensible author wants anything but praise.', "It's sort of my job to feel good.", "There are times I can't even figure myself out.", 'A film has its own life and takes its own time.', 'I would like to direct.', "I'd like to do a romantic comedy.", "I'd like to do more family dramas.", 'There are different reasons to make movies.', 'Better to be disliked than pitied.', 'His ignorance is encyclopedic.', 'As a child, the paddy field was my playground.', 'They took away time, and they gave us the clock.', "I'm about my characters.", "I don't care if I get $50 million to do a film.", "I don't care if I get $50m to do a film.", "I don't have a problem with Werner Herzog.", 'I live with a bunch of yuppies and models.', 'I like working on my birthday, so I always do.', 'Great necessities call out great virtues.', 'Be modest, humble, simple. Control your anger.', 'I was a great dreamer of day dreams.', 'Life is much shorter than I imagined it to be.', 'What is wealth? A dream of fools.', 'You must never tire fighting Satan.', 'Whatever you are, be a good one.', 'Allah will help him who moves in the way of Allah.', 'Knowledge is the life of the mind.', "I'm like a fungus; you can't get rid of me.", "I'm not much of a jokester.", 'I think work begets work.', "I'm no Leonardo DiCaprio.", "I've never been more normal than I am now.", 'Crying is really bad for your vocal cords.', 'Most modern comedy is crap.', "I'm huge fan of 'Timeflies.'", 'From a small seed a mighty trunk may grow.', 'God always strives together with those who strive.', 'Time brings all things to pass.', 'God loves to help him who strives to help himself.', 'The words of truth are simple.', 'But time growing old teaches all things.', 'For know that no one is free, except Zeus.', 'I know how men in exile feed on dreams.', 'Gratitude is the sign of noble souls.', 'Appearances are often deceiving.', 'It is not only fine feathers that make fine birds.', 'It is easy to be brave from a safe distance.', 'United we stand, divided we fall.', 'Please all, and you will please none.', 'Example is the best precept.', 'The smaller the mind the greater the conceit.', 'Persuasion is often more effectual than force.', 'Adventure is worthwhile.', "It ain't no joke when you lose your vinyl.", 'Cars for me are like a piece of art.', "I have a living room full of clothes. It's insane.", 'Very few of us are what we seem.', 'I just want to live in peace and quiet.', 'I must be allowed to be as I am.', 'I sing just for fun.', "I'm a country bumpkin. I'm not a showgirl.", "I'm dating a very high-maintenance career.", "I don't even know what street Canada is on.", 'I have built my organization upon fear.', 'Now I know why tigers eat their young.', 'Prohibition has made nothing but trouble.', 'Vote early and vote often.', "I think sexuality is a window into someone's soul.", 'A country song is a song about life.', "I've always wanted to make a bluegrass album.", "Oklahoma's always been good to me.", 'You just write about things that happen.', "I'm usually just enjoying life.", 'Reality is only a Rorschach ink-blot, you know.', 'I like having the freedom to dress as I desire.', "I hate the word 'cool.' It gives me a rash.", 'I am very much a people person.', 'You cannot create experience. You must undergo it.', 'I know of only one duty, and that is to love.', 'Freedom is nothing but a chance to be better.', 'No cause justifies the deaths of innocent people.', 'The only source of knowledge is experience.', 'Only a life lived for others is a life worthwhile.', 'The art of love is largely the art of persistence.', 'Do something wonderful, people may imitate it.', 'Example is leadership.', 'Ethics is nothing else than reverence for life.', 'Dream in a pragmatic way.', 'Getting older is hard.', 'A camel is a horse designed by committee.', 'I feel pride in being a Greenl ...

# %%
class Vocabulary:
    def __init__(self, sentences):
        all_characters = set()
        for line in sentences:
            all_characters |= set(line)
        all_characters = list(sorted(all_characters)) + ['<eos>', '<go>']
        self.char_to_id = {x[1]:x[0] for x in enumerate(all_characters)}
        self.id_to_char = {x[0]:x[1] for x in enumerate(all_characters)}
        self.size = len(all_characters)

    def encode(self, line):
        return [self.char_to_id[x] for x in line]
    
    def decode(self, tokens):
        return ''.join([self.id_to_char[x] for x in tokens])

# %%
vocab = Vocabulary(lines)

# %%
print(vocab.encode(lines[0]))
assert vocab.decode(vocab.encode(lines[0])) == lines[0]
# Out:
# [43, 51, 51, 50, 65, 0, 47, 64, 51, 0, 52, 58, 61, 69, 51, 64, 65, 0, 66, 61, 61, 5, 0, 61, 60, 49, 51, 0, 71, 61, 67, 0, 53, 51, 66, 0, 66, 61, 0, 57, 60, 61, 69, 0, 66, 54, 51, 59, 7]

# %%
class Quotes(Dataset):
    def __init__(self, sentences, vocab):
        # Construct vocabulary + EOS & GO tokens
        self.sentences = sentences
        self.vocab = vocab
        
    def __len__(self):
        return len(self.sentences)
        
    def __getitem__(self, idx):
        tokens = self.vocab.encode(self.sentences[idx])
        input = np.array([self.go] + tokens)
        output = np.array(tokens + [self.eos])
        return input, output

# %%
def compose_batch(batch):
    order = np.argsort(-len(x[0]) for x in batch)
    lengths = [len(x[0]) for x in batch]
    go = torch.zeros((len(batch), lengths[order[0]]))
    eos = torch.zeros((len(batch), lengths[order[0]]))
    mask = torch.zeros((len(batch), lengths[order[0]]))
    for i in range(len(batch)):
        current_go, current_eos = batch[i]
        go[i, :len(current_go)] = torch.tensor(current_go)
        eos[i, :len(current_eos)] = torch.tensor(current_eos)
        mask[i, :len(current_go)] = 1
    mask = mask[order]
    go = go[order]
    return go, eos, mask, -lengths

# %%
dataset = Quotes(lines, vocab)

# %%
dataloader = DataLoader(dataset, shuffle=True)

# %%
go = next(iter(dataloader))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-337668ca2e04> in <module>()
# ----> 1 go = next(iter(dataloader))
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     312         if self.num_workers == 0:  # same-process loading
#     313             indices = next(self.sample_iter)  # may raise StopIteration
# --> 314             batch = self.collate_fn([self.dataset[i] for i in indices])
#     315             if self.pin_memory:
#     316                 batch = pin_memory_batch(batch)
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     312         if self.num_workers == 0:  # same-process loading
#     313             indices = next(self.sample_iter)  # may raise StopIteration
# --> 314             batch = self.collate_fn([self.dataset[i] for i in indices])
#     315             if self.pin_memory:
#     316                 batch = pin_memory_batch(batch)
#
# <ipython-input-74-d4f835035ba2> in __getitem__(self, idx)
#      10     def __getitem__(self, idx):
#      11         tokens = self.vocab.encode(self.sentences[idx])
# ---> 12         input = np.array([self.go] + tokens)
#      13         output = np.array(tokens + [self.eos])
#      14         return input, output
#
# AttributeError: 'Quotes' object has no attribute 'go'

# %% [markdown]
# ### Часть 2: определение модели

# %%
class Oracle(nn.Module):
    def __init__(self, vocabulary_size, embedding_size=128, hidden_size=256, layers=2):
        super(Oracle, self).__init__()
        self.embedding_size = embedding_size
        self.layers = layers
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(vocabulary_size, embedding_size)
        self.generator = nn.GRU(embedding_size, hidden_size, layers, batch_first=True)
        self.classifier = nn.Linear(hidden_size, vocabulary_size)
    
    def forward(self, input):
        embedding = self.embedding(input)
        h = Variable(torch.zeros(self.layers, 1, self.hidden_size))
        output, _ = self.generator(embedding, (h))
        classes = self.classifier(output[0])
        return classes
    
    def generate(self, vocab, max_len=100):
        # TODO: replace with sampling
        h = Variable(torch.zeros(self.layers, 1, self.hidden_size))
        current_token = '<go>'
        line = ''
        while (current_token != '<eos>') and len(line) < max_len:
            token = torch.Tensor([[vocab.char_to_id[current_token]]]).long()
            token_id = Variable(token, volatile=True)
            embedding = self.embedding(token_id)
            output, (h) = self.generator(embedding, (h))
            classes = self.classifier(output[0])
            new_token_id = np.argmax(classes.data.numpy()) # torch.distributions.Categorical(classes_probs[0])
            current_token = vocab.id_to_char[new_token_id]
            line = line + current_token
        return line

# %%
oracle = Oracle(vocab.size, embedding_size=32, hidden_size=64, layers=2)

# %% [markdown]
# ### Часть 3: обучение модели

# %%
import progressbar
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-55-aa73c21ff055> in <module>()
# ----> 1 import progressbar
#
# ModuleNotFoundError: No module named 'progressbar'

# %%
optimizer = torch.optim.Adam(oracle.parameters(), lr=0.01)

# %%
criterion = nn.CrossEntropyLoss()

# %%
losses = []

# %%
for epoch in range(1000):
    bar = progressbar.ProgressBar()
    
    for i, (batch, target) in enumerate(dataloader):
        batch = Variable(batch)
        target = Variable(target, requires_grad=False)[0]
        prediction = oracle(batch)
        loss = criterion(prediction, target)
        loss.backward()
        if i%32 == 0: # aka batch
            optimizer.step()
            oracle.zero_grad()
            losses.append(loss.data[0])
            print(loss.data[0], oracle.generate(vocab))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-e418ebebaa3c> in <module>()
#       1 for epoch in range(1000):
# ----> 2     bar = progressbar.ProgressBar()
#       3
#       4     for i, (batch, target) in enumerate(dataloader):
#       5         batch = Variable(batch)
#
# NameError: name 'progressbar' is not defined

# %%
oracle.generate(vocab)
# Out:
# 'I love the be and the what the the the the the the the the the the the the the the the the the the t'

# %% [markdown]
# ### Часть 4: оценивание модели

# %% [markdown]
# <i> Приведите примеры сгенерированных предложений </i>

# %%
plt.plot(losses)

# %% [markdown]
# #### Feedback (опционально)

# %% [markdown]
# Здесь вы можете оставить список опечаток из лекции или семинара:

# %% [markdown]
# Здесь вы можете оставить комментарии по лекции или семинару:
